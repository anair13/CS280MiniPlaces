# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import Image
import cv2
from caffe_graphics import *
from matplotlib import colors
colornames = [i[0] for i in colors.cnames.items()]

# Make sure that caffe is on the python path:
caffe_root = '../../../'  # this file is expected to be in {caffe_root}/examples
import sys
sys.path.insert(0, caffe_root + 'python')

import caffe

# configure plotting
plt.rcParams['figure.figsize'] = (5, 5)
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

caffe.set_mode_gpu()
print "done"

import caffe.io
from caffe.proto.caffe_pb2 import BlobProto
from ashvin_utils import *
# Out:
# done

# %%
def plot_loss(step = 50, pref=""):
    train_loss = np.load("snapshot_solver_deeper/training_loss.npy")
    test_loss = np.load("snapshot_solver_deeper/test_loss.npy")
    plt.figure(figsize=(5,5))
    plt.plot(test_loss)
    plt.axis([0, len(test_loss), 0, 7])
    plt.figure(figsize=(5,5))
    plt.plot(train_loss)
    plt.axis([0, len(train_loss), 0, 7])
    plt.figure(figsize=(5,5))
    plt.plot(range(0, len(train_loss), step), test_loss)
    plt.plot(train_loss)
    plt.axis([0, len(train_loss), 0, 7])
    return train_loss, test_loss

# %%
plot_loss(100)
# Out:
# (array([ 4.60517025,  7.52501774,  4.73505306, ...,  1.24961543,
#          1.28489852,  1.39477336]),
#  array([ 6.71237602,  4.59639864,  4.41985283,  4.2993926 ,  4.215765  ,
#          4.06825361,  4.02344427,  4.02599206,  3.93636999,  3.82427802,
#          3.77981567,  3.71088629,  3.73933821,  3.58693671,  3.53964329,
#          3.50398755,  3.46846056,  3.37498622,  3.40012288,  3.36087227,
#          3.28341045,  3.30247669,  3.23013477,  3.20043612,  3.11183815,
#          3.14099822,  3.15681319,  3.17097955,  3.06625662,  3.04873896,
#          3.06782513,  3.02169175,  2.93172235,  2.96302466,  2.93474679,
#          2.87056637,  2.90709686,  2.91723757,  2.84598403,  2.8061089 ,
#          2.77432594,  2.88160367,  2.94658914,  2.72490001,  2.79677162,
#          2.77592115,  2.722826  ,  2.85915279,  2.60004363,  2.70210838,
#          2.70627718,  2.66319804,  2.58893495,  2.71435647,  2.7429594 ,
# ...
